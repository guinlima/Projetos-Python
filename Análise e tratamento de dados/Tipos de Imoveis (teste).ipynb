# %% [markdown]
# # Relatórios de Análise II

# %% [markdown]
# ## Tipos de Imóveis

# %%
import pandas as pd

# %%
dados = pd.read_csv('dados/aluguel.csv',sep = ";")
dados.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-49ad047eb11f> in <module>
# ----> 1 dados = pd.read_csv('dados/aluguel.csv',sep = ";")
#       2 dados.head()
#
# NameError: name 'pd' is not defined

# %%
dados["Tipo"]
# Out:
# 0                      Quitinete
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                    Apartamento
# 4                    Apartamento
# 5                    Apartamento
# 6                    Apartamento
# 7             Casa de Condomínio
# 8             Casa de Condomínio
# 9        Conjunto Comercial/Sala
# 10                   Apartamento
# 11                   Apartamento
# 12                   Apartamento
# 13                   Apartamento
# 14                     Quitinete
# 15                   Apartamento
# 16                Prédio Inteiro
# 17                          Flat
# 18            Casa de Condomínio
# 19                   Apartamento
# 20                   Apartamento
# 21                   Apartamento
# 22            Casa de Condomínio
# 23                   Apartamento
# 24                   Apartamento
# 25                          Flat
# 26       Conjunto Comercial/Sala
# 27                   Apartamento
# ...

# %%
dados.Tipo
# Out:
# 0                      Quitinete
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                    Apartamento
# 4                    Apartamento
# 5                    Apartamento
# 6                    Apartamento
# 7             Casa de Condomínio
# 8             Casa de Condomínio
# 9        Conjunto Comercial/Sala
# 10                   Apartamento
# 11                   Apartamento
# 12                   Apartamento
# 13                   Apartamento
# 14                     Quitinete
# 15                   Apartamento
# 16                Prédio Inteiro
# 17                          Flat
# 18            Casa de Condomínio
# 19                   Apartamento
# 20                   Apartamento
# 21                   Apartamento
# 22            Casa de Condomínio
# 23                   Apartamento
# 24                   Apartamento
# 25                          Flat
# 26       Conjunto Comercial/Sala
# 27                   Apartamento
# ...

# %%
tipo_de_imovel = dados["Tipo"]

# %%
type(tipo_de_imovel)
# Out:
# pandas.core.series.Series

# %%
tipo_de_imovel.unique() #para ver quais são os valores unicos da variável
# Out:
# array(['Quitinete', 'Casa', 'Conjunto Comercial/Sala', 'Apartamento',
#        'Casa de Condomínio', 'Prédio Inteiro', 'Flat', 'Loja/Salão',
#        'Galpão/Depósito/Armazém', 'Casa Comercial', 'Casa de Vila',
#        'Terreno Padrão', 'Box/Garagem', 'Loft',
#        'Loja Shopping/ Ct Comercial', 'Chácara', 'Loteamento/Condomínio',
#        'Sítio', 'Pousada/Chalé', 'Studio', 'Hotel', 'Indústria'],
#       dtype=object)

# %%
type(tipo_de_imovel.unique())
# Out:
# numpy.ndarray

# %%
tipo_de_imovel.drop_duplicates(inplace=True)

# %%
tipo_de_imovel
# Out:
# 0                          Quitinete
# 1                               Casa
# 2            Conjunto Comercial/Sala
# 3                        Apartamento
# 7                 Casa de Condomínio
# 16                    Prédio Inteiro
# 17                              Flat
# 29                        Loja/Salão
# 80           Galpão/Depósito/Armazém
# 83                    Casa Comercial
# 117                     Casa de Vila
# 159                   Terreno Padrão
# 207                      Box/Garagem
# 347                             Loft
# 589      Loja Shopping/ Ct Comercial
# 2157                         Chácara
# 3354           Loteamento/Condomínio
# 4379                           Sítio
# 4721                   Pousada/Chalé
# 6983                          Studio
# 9687                           Hotel
# 23614                      Indústria
# Name: Tipo, dtype: object

# %% [markdown]
# ## Organizando a visualização

# %%
tipo_de_imovel = tipo_de_imovel.to_frame()
#ou
tipo_de_imovel = pd.DataFrame(tipo_de_imovel)
tipo_de_imovel
# Out:
#                               Tipo
# 0                        Quitinete
# 1                             Casa
# 2          Conjunto Comercial/Sala
# 3                      Apartamento
# 7               Casa de Condomínio
# 16                  Prédio Inteiro
# 17                            Flat
# 29                      Loja/Salão
# 80         Galpão/Depósito/Armazém
# 83                  Casa Comercial
# 117                   Casa de Vila
# 159                 Terreno Padrão
# 207                    Box/Garagem
# 347                           Loft
# 589    Loja Shopping/ Ct Comercial
# 2157                       Chácara
# 3354         Loteamento/Condomínio
# 4379                         Sítio
# 4721                 Pousada/Chalé
# 6983                        Studio
# 9687                         Hotel
# 23614                    Indústria

# %%
import numpy as np
tipo_de_imovel.index = np.arange(tipo_de_imovel.shape[0])
#ou
tipo_de_imovel.index = range(tipo_de_imovel.shape[0])

# %%
tipo_de_imovel
# Out:
#                            Tipo
# 0                     Quitinete
# 1                          Casa
# 2       Conjunto Comercial/Sala
# 3                   Apartamento
# 4            Casa de Condomínio
# 5                Prédio Inteiro
# 6                          Flat
# 7                    Loja/Salão
# 8       Galpão/Depósito/Armazém
# 9                Casa Comercial
# 10                 Casa de Vila
# 11               Terreno Padrão
# 12                  Box/Garagem
# 13                         Loft
# 14  Loja Shopping/ Ct Comercial
# 15                      Chácara
# 16        Loteamento/Condomínio
# 17                        Sítio
# 18                Pousada/Chalé
# 19                       Studio
# 20                        Hotel
# 21                    Indústria

# %%
tipo_de_imovel.index
# Out:
# RangeIndex(start=0, stop=22, step=1)

# %%
tipo_de_imovel.columns.name = "Id"

# %%
tipo_de_imovel.rename({'Tipo':'Amigo'},axis = 'columns')
# Out:
# Id                        Amigo
# 0                     Quitinete
# 1                          Casa
# 2       Conjunto Comercial/Sala
# 3                   Apartamento
# 4            Casa de Condomínio
# 5                Prédio Inteiro
# 6                          Flat
# 7                    Loja/Salão
# 8       Galpão/Depósito/Armazém
# 9                Casa Comercial
# 10                 Casa de Vila
# 11               Terreno Padrão
# 12                  Box/Garagem
# 13                         Loft
# 14  Loja Shopping/ Ct Comercial
# 15                      Chácara
# 16        Loteamento/Condomínio
# 17                        Sítio
# 18                Pousada/Chalé
# 19                       Studio
# 20                        Hotel
# 21                    Indústria

# %%
tipo_de_imovel
# Out:
# Id                         Tipo
# 0                     Quitinete
# 1                          Casa
# 2       Conjunto Comercial/Sala
# 3                   Apartamento
# 4            Casa de Condomínio
# 5                Prédio Inteiro
# 6                          Flat
# 7                    Loja/Salão
# 8       Galpão/Depósito/Armazém
# 9                Casa Comercial
# 10                 Casa de Vila
# 11               Terreno Padrão
# 12                  Box/Garagem
# 13                         Loft
# 14  Loja Shopping/ Ct Comercial
# 15                      Chácara
# 16        Loteamento/Condomínio
# 17                        Sítio
# 18                Pousada/Chalé
# 19                       Studio
# 20                        Hotel
# 21                    Indústria
