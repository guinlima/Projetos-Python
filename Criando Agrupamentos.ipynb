# %% [markdown]
# # Relatório de Análise VII

# %% [markdown]
# ## Criando Agrupamentos

# %%
import pandas as pd

# %%
dados = pd.read_csv('dados/alugue_residencial.csv',sep = ";")

# %%
dados.head()
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 2  Apartamento           Centro        1      0       0    15   800.0
# 3  Apartamento     Higienópolis        1      0       0    48   800.0
# 4  Apartamento         Cachambi        2      0       0    50  1300.0
#
#    Condominio  IPTU  Valor m2 Tipo Agregado
# 0       500.0  60.0     42.50     Quitinete
# 1         0.0   0.0     70.00          Casa
# 2       390.0  20.0     53.33   Apartamento
# 3       230.0   0.0     16.67   Apartamento
# 4       301.0  17.0     26.00   Apartamento

# %%
dados['Valor'].mea
# Out:
# 5046.172821405663

# %%
bairrinho = dados.Bairro.value_counts()

# %%
bairrinho.iloc[0:1000]
# Out:
# Barra da Tijuca             3863
# Copacabana                  2644
# Ipanema                     1764
# Recreio dos Bandeirantes    1649
# Leblon                      1258
# Tijuca                      1100
# Botafogo                     873
# Flamengo                     714
# Lagoa                        488
# Freguesia (Jacarepaguá)      456
# Campo Grande                 449
# Laranjeiras                  425
# Centro                       343
# Vila Isabel                  300
# Jardim Botânico              263
# São Conrado                  259
# Méier                        255
# Jacarepaguá                  245
# Leme                         229
# Gávea                        215
# Pechincha                    202
# Taquara                      171
# Catete                       160
# Humaitá                      158
# Grajaú                       145
# Cachambi                     132
# Maracanã                     129
# Santa Teresa                 114
# ...

# %%
bairrinho = pd.DataFrame(bairrinho)

# %%
bairrin

# %%
bairros = dados.groupby('Bairro')

# %%
type(bairros)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
for bairro,data in bairros:
    print('{} -> {}'.format(bairro,data.Valor.mean()))
# Out:
# Abolição -> 1195.3333333333333
# Alto da Boa Vista -> 3966.6666666666665
# Anchieta -> 875.0
# Andaraí -> 1464.7113402061855
# Anil -> 2048.8732394366198
# Arpoador -> 12923.916666666666
# Bancários -> 1825.0
# Bangu -> 1016.0
# Barra da Tijuca -> 7069.552938130986
# Barra de Guaratiba -> 5550.0
# Benfica -> 996.0
# Bento Ribeiro -> 1030.8695652173913
# Bonsucesso -> 1225.9322033898304
# Botafogo -> 8791.828178694159
# Braz de Pina -> 1115.0
# Cachambi -> 1157.1742424242425
# Cachamorra -> 3000.0
# Cacuia -> 916.6666666666666
# Caju -> 850.0
# Camorim -> 1735.2272727272727
# Campinho -> 1037.3333333333333
# Campo Grande -> 1267.71714922049
# Cascadura -> 948.7096774193549
# Catete -> 2267.0625
# Catumbi -> 1112.5
# Cavalcanti -> 595.0
# Centro -> 1254.7521865889212
# Cidade Jardim -> 12000.0
# Cidade Nova -> 1471.4285714285713
# Cocotá -> 1883.3333333333333
# Coelho Neto -> 700.0
# Colégio -> 885.0
# Copacabana -> 4126.677004538578
# Cordovil -> 905.5555555555555
# ...

# %%
bairros["Valor"].mean()
# Out:
# Bairro
# Abolição                 1195.333333
# Alto da Boa Vista        3966.666667
# Anchieta                  875.000000
# Andaraí                  1464.711340
# Anil                     2048.873239
# Arpoador                12923.916667
# Bancários                1825.000000
# Bangu                    1016.000000
# Barra da Tijuca          7069.552938
# Barra de Guaratiba       5550.000000
# Benfica                   996.000000
# Bento Ribeiro            1030.869565
# Bonsucesso               1225.932203
# Botafogo                 8791.828179
# Braz de Pina             1115.000000
# Cachambi                 1157.174242
# Cachamorra               3000.000000
# Cacuia                    916.666667
# Caju                      850.000000
# Camorim                  1735.227273
# Campinho                 1037.333333
# Campo Grande             1267.717149
# Cascadura                 948.709677
# Catete                   2267.062500
# Catumbi                  1112.500000
# ...

# %%
bairros[["Valor","Condominio"]].mean().round(2)
# Out:
#                          Valor  Condominio
# Bairro
# Abolição               1195.33      191.40
# Alto da Boa Vista      3966.67      885.00
# Anchieta                875.00       19.75
# Andaraí                1464.71      497.71
# Anil                   2048.87      455.85
# Arpoador              12923.92     3493.92
# Bancários              1825.00      217.00
# Bangu                  1016.00       92.25
# Barra da Tijuca        7069.55     3591.01
# Barra de Guaratiba     5550.00     1600.00
# Benfica                 996.00      136.60
# Bento Ribeiro          1030.87      130.39
# Bonsucesso             1225.93      313.12
# Botafogo               8791.83      976.28
# Braz de Pina           1115.00      161.50
# Cachambi               1157.17      452.77
# Cachamorra             3000.00      200.00
# Cacuia                  916.67      248.00
# Caju                    850.00      230.00
# Camorim                1735.23     1524.23
# Campinho               1037.33      364.87
# ...

# %% [markdown]
# ## Estatísticas Descritivas

# %%
bairros["Valor"].describe()
# Out:
#                        count          mean            std      min      25%  \
# Bairro
# Abolição                15.0   1195.333333     425.321167    800.0    900.0
# Alto da Boa Vista        6.0   3966.666667    5513.589273    600.0   1150.0
# Anchieta                 4.0    875.000000     132.287566    700.0    812.5
# Andaraí                 97.0   1464.711340     408.105582    700.0   1200.0
# Anil                    71.0   2048.873239    1523.974643    300.0   1100.0
# Arpoador                12.0  12923.916667    9064.211869   4200.0   7325.0
# Bancários                4.0   1825.000000     665.206735   1300.0   1525.0
# Bangu                   20.0   1016.000000     347.235700    400.0    825.0
# Barra da Tijuca       3863.0   7069.552938   11874.152437    800.0   2500.0
# Barra de Guaratiba       4.0   5550.000000    2716.001964   2200.0   3925.0
# Benfica                  5.0    996.000000     205.012195    790.0    790.0
# ...

# %%
bairros["Valor"].aggregate(["min","max"]).rename(columns = {"min": "Minimo","max":"Maximo"})
# Out:
#                        Minimo     Maximo
# Bairro
# Abolição                800.0     2300.0
# Alto da Boa Vista       600.0    15000.0
# Anchieta                700.0     1000.0
# Andaraí                 700.0     2950.0
# Anil                    300.0     7000.0
# Arpoador               4200.0    30000.0
# Bancários              1300.0     2800.0
# Bangu                   400.0     1650.0
# Barra da Tijuca         800.0   600000.0
# Barra de Guaratiba     2200.0     8000.0
# Benfica                 790.0     1200.0
# Bento Ribeiro           480.0     2200.0
# Bonsucesso              600.0     4500.0
# Botafogo                700.0  4500000.0
# Braz de Pina            450.0     2300.0
# Cachambi                600.0     2800.0
# Cachamorra             3000.0     3000.0
# Cacuia                  800.0     1050.0
# Caju                    850.0      850.0
# Camorim                 800.0     6000.0
# Campinho                650.0     1700.0
# Campo Grande            400.0    12000.0
# ...

# %%
import matplotlib.pyplot as plt
plt.rc('figure',figsize = (20,10))

# %%
fig = bairros["Valor"].mean().plot.bar(color = "blue")
fig.set_ylabel("Valor do Aluguel")
fig.set_title("Valor médio do Aluguel por Bairro",{"fontsize":22})
# Out:
# Text(0.5, 1.0, 'Valor médio do Aluguel por Bairro')
