# %%
#1 - Data science

# %%
import pandas as pd

# %%
notas = pd.read_csv("dados/ratings.csv")

# %%
notas
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# 5            1       70     3.0   964982400
# 6            1      101     5.0   964980868
# 7            1      110     4.0   964982176
# 8            1      151     5.0   964984041
# 9            1      157     5.0   964984100
# 10           1      163     5.0   964983650
# 11           1      216     5.0   964981208
# 12           1      223     3.0   964980985
# 13           1      231     5.0   964981179
# 14           1      235     4.0   964980908
# 15           1      260     5.0   964981680
# 16           1      296     3.0   964982967
# 17           1      316     3.0   964982310
# 18           1      333     5.0   964981179
# 19           1      349     4.0   964982563
# ...

# %%
notas.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
notas.shape
# Out:
# (100836, 4)

# %%
notas.columns = ["usuarioid","filmeid","nota","momento"]

# %%
notas.head()
# Out:
#    usuarioid  filmeid  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
type(notas)
# Out:
# pandas.core.frame.DataFrame

# %%
notas["nota"].head()
# Out:
# 0    4.0
# 1    4.0
# 2    4.0
# 3    5.0
# 4    5.0
# Name: nota, dtype: float64

# %%
notas[["nota"]].head()
# Out:
#    nota
# 0   4.0
# 1   4.0
# 2   4.0
# 3   5.0
# 4   5.0

# %%
notas.loc[:,["nota"]].head()
# Out:
#    nota
# 0   4.0
# 1   4.0
# 2   4.0
# 3   5.0
# 4   5.0

# %%
notas["nota"].unique()
# Out:
# array([4. , 5. , 3. , 2. , 1. , 4.5, 3.5, 2.5, 0.5, 1.5])

# %%
notas['nota'].value_counts()
# Out:
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: nota, dtype: int64

# %%
print(notas['nota'].mean())
print(notas['nota'].median())
# Out:
# 3.501556983616962
# 3.5

# %%
# Visualização de Dados

# %%
notas.nota.head()
# Out:
# 0    4.0
# 1    4.0
# 2    4.0
# 3    5.0
# 4    5.0
# Name: nota, dtype: float64

# %%
notas.nota.plot()

# %%
notas.nota.plot(kind="hist")

# %%
notas.nota.describe()
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: nota, dtype: float64

# %%
import seaborn as sns

# %%
sns.boxplot(notas.nota)

# %%
from scipy.stats import shapiro,anderson,normaltest
p = shapiro(notas.nota)
print(p)
n = normaltest(notas.nota)
print(n)
# Out:
# C:\Users\limag\Anaconda3\lib\site-packages\scipy\stats\morestats.py:1653: UserWarning: p-value may not be accurate for N > 5000.
#   warnings.warn("p-value may not be accurate for N > 5000.")
# (0.9344640374183655, 0.0)
# NormaltestResult(statistic=5822.370481158027, pvalue=0.0)

# %%
import numpy as np
j=np.random.normal(10,1,100000)

# %%
p = shapiro(j)
print(p)
n = normaltest(j)
print(n)
# Out:
# (0.9999808669090271, 0.934268057346344)
# NormaltestResult(statistic=0.7985372378834364, pvalue=0.6708104847472263)

# %%
pd.Series(j).plot(kind="hist")

# %%
pd.Series(j).describe()
# Out:
# count    100000.000000
# mean          9.995242
# std           1.001372
# min           5.898777
# 25%           9.317104
# 50%           9.998185
# 75%          10.672531
# max          15.121646
# dtype: float64

# %%
sns.distplot(j)

# %%
# 2 - Análise Exploratória de Dados

# %%
filmes = pd.read_csv("dados/movies.csv")

# %%
filmes.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
notas.head()
# Out:
#    usuarioid  filmeid  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
filmes.columns = ["filmeid","titulo","generos"]
filmes.head()
# Out:
#    filmeid                              titulo  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                        generos
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
notas.query("filmeid ==1").nota.mean()
# Out:
# 3.9209302325581397

# %%
 notas.groupby("filmeid")

# %%
medias_por_filme = notas.groupby("filmeid").mean()["nota"]

# %%
medias_por_filme.plot(kind = "hist")

# %%
tmdb = pd.read_csv("dados/tmdb_5000_movies.csv")
tmdb
# Out:
#          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5     258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6     260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7     280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8     250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9     250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 10    270000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 11    200000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 12    200000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# ...

# %%
tmdb.original_language.unique()
# Out:
# array(['en', 'ja', 'fr', 'zh', 'es', 'de', 'hi', 'ru', 'ko', 'te', 'cn',
#        'it', 'nl', 'ta', 'sv', 'th', 'da', 'xx', 'hu', 'cs', 'pt', 'is',
#        'tr', 'nb', 'af', 'pl', 'he', 'ar', 'vi', 'ky', 'id', 'ro', 'fa',
#        'no', 'sl', 'ps', 'el'], dtype=object)

# %%
tmdb.original_language.value_counts()
# Out:
# en    4505
# fr      70
# es      32
# zh      27
# de      27
# hi      19
# ja      16
# it      14
# cn      12
# ru      11
# ko      11
# pt       9
# da       7
# sv       5
# fa       4
# nl       4
# he       3
# th       3
# cs       2
# ro       2
# ta       2
# ar       2
# id       2
# sl       1
# is       1
# ky       1
# nb       1
# el       1
# te       1
# vi       1
# ps       1
# hu       1
# pl       1
# tr       1
# af       1
# xx       1
# no       1
# Name: original_language, dtype: int64

# %%
tmdb.original_language.value_counts().to_frame().reset_index()
# Out:
#    index  original_language
# 0     en               4505
# 1     fr                 70
# 2     es                 32
# 3     zh                 27
# 4     de                 27
# 5     hi                 19
# 6     ja                 16
# 7     it                 14
# 8     cn                 12
# 9     ru                 11
# 10    ko                 11
# 11    pt                  9
# 12    da                  7
# 13    sv                  5
# 14    fa                  4
# 15    nl                  4
# 16    he                  3
# 17    th                  3
# 18    cs                  2
# 19    ro                  2
# 20    ta                  2
# 21    ar                  2
# 22    id                  2
# 23    sl                  1
# 24    is                  1
# 25    ky                  1
# 26    nb                  1
# 27    el                  1
# 28    te                  1
# 29    vi                  1
# 30    ps                  1
# 31    hu                  1
# ...

# %%
contagem_de_lingua = tmdb.original_language.value_counts().to_frame().reset_index()
contagem_de_lingua.columns = ["original_language","total"]
contagem_de_lingua
# Out:
#    original_language  total
# 0                 en   4505
# 1                 fr     70
# 2                 es     32
# 3                 zh     27
# 4                 de     27
# 5                 hi     19
# 6                 ja     16
# 7                 it     14
# 8                 cn     12
# 9                 ru     11
# 10                ko     11
# 11                pt      9
# 12                da      7
# 13                sv      5
# 14                fa      4
# 15                nl      4
# 16                he      3
# 17                th      3
# 18                cs      2
# 19                ro      2
# 20                ta      2
# 21                ar      2
# 22                id      2
# 23                sl      1
# 24                is      1
# 25                ky      1
# 26                nb      1
# 27                el      1
# 28                te      1
# 29                vi      1
# 30                ps      1
# 31                hu      1
# ...

# %%
sns.barplot(x="original_language",y="total",data=contagem_de_lingua)

# %%
sns.catplot(x="original_language",kind = "count",data=tmdb)

# %%
filmes.head()
# Out:
#    filmeid                              titulo  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                        generos
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
notas.head()
# Out:
#    usuarioid  filmeid  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
notas.shape
# Out:
# (100836, 4)

# %%
notas.columns=
# Out:
# Index(['usuarioid', 'filmeid', 'nota', 'momento'], dtype='object')

# %%
nota_media=notas.groupby(["filmeid"]).nota.mean().to_frame().reset_index()

# %%
nota_media.columns = ["filmeid","nota_media"]
#or
#nota_media.rename(columns={"nota":"nota_media"})

# %%
nota_media.head()
# Out:
#    filmeid  nota_media
# 0        1    3.920930
# 1        2    3.431818
# 2        3    3.259615
# 3        4    2.357143
# 4        5    3.071429

# %%
notas.head()
# Out:
#    usuarioid  filmeid  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
filmes.head()
# Out:
#    filmeid                              titulo  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                        generos
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
n_usuarios = notas.filmeid.value_counts().to_frame().reset_index()

# %%
n_usuarios.columns = ["filmeid","n_usuarios"]

# %%
n_usuarios.head()
# Out:
#    filmeid  n_usuarios
# 0      356         329
# 1      318         317
# 2      296         307
# 3      593         279
# 4     2571         278

# %%
result1 = pd.merge(filmes,nota_media,on="filmeid")

# %%
result1.head()
# Out:
#    filmeid                              titulo  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                        generos  nota_media
# 0  Adventure|Animation|Children|Comedy|Fantasy    3.920930
# 1                   Adventure|Children|Fantasy    3.431818
# 2                               Comedy|Romance    3.259615
# 3                         Comedy|Drama|Romance    2.357143
# 4                                       Comedy    3.071429

# %%
result2 = pd.merge(result1,n_usuarios,on="filmeid")

# %%
result2.head()
# Out:
#    filmeid                              titulo  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                        generos  nota_media  n_usuarios
# 0  Adventure|Animation|Children|Comedy|Fantasy    3.920930         215
# 1                   Adventure|Children|Fantasy    3.431818         110
# 2                               Comedy|Romance    3.259615          52
# 3                         Comedy|Drama|Romance    2.357143           7
# 4                                       Comedy    3.071429          49
